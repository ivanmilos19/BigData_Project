# %%
import os
from datetime import date
import pandas as pd


DATALAKE_ROOT_FOLDER = "C:/BigData_project/"
current_day = date.today().strftime("%Y%m%d")
parquet_file_path = os.path.join(DATALAKE_ROOT_FOLDER, "airflow", "datalake", "usage", "animeAnalysis", "AnimeTop300", "20240614", "combined_ratings.snappy.parquet")

df_combined = pd.read_parquet(parquet_file_path)

df_combined.head(1000)
# Out:
#          id        english_title_MAL  averageScore_MAL  ranking_MAL  \
# 0         1             Cowboy Bebop              8.75           46
# 1         5  Cowboy Bebop: The Movie              8.38          202
# 2        19                  Monster              8.88           24
# 3        21                One Piece              8.72           53
# 4        30  Neon Genesis Evangelion              8.35          228
# ..      ...                      ...               ...          ...
# 515  164117                                      -1.00           -1
# 516  164212                                      -1.00           -1
# 517  166216                                      -1.00           -1
# 518  166794                                      -1.00           -1
# 519  166873                                      -1.00           -1
#
#                                             genres_MAL  \
# 0                      [Action, Award Winning, Sci-Fi]
# ...
